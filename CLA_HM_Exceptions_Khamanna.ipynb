# %%
def int_plus_string(a,s):
    result = a+ s
    if (type(a) == int & type(s) == str):
        raise Exception("integer cant be added to a string")
    else:
        return result

print(12,'hello')
