# %% [markdown]
# Given the file “student_names.txt” do the following:
#
# Read all of the content of the file in one variable.
# Write a list of random names to your file.
# Print the first n lines of the file.
# Print the last n lines of the file.
# Check if the name x is in the file.
# Write a Python program to generate 26 text files named A.txt, B.txt, and so on up to Z.txt.

# %%
file = open("../Downloads/student_names.txt")
students=file.read()
file.close()
students
# Out:
# '\nEmma Watson\nEmma Watsonli\nSevil Huseynli\nKhamanna Iskandarova'

# %%
students = students + " \nEmma Watson" + " \nKate Bessingdale"
students
# Out:
# '\nEmma Watson\nEmma Watsonli\nSevil Huseynli\nKhamanna Iskandarova \nEmma Watson \nKate Bessingdale'

# %%
a_file = open("../Downloads/student_names.txt", "r")
lines = a_file.readlines()
lines[:2]
first_lines = lines[:2]
print(first_lines)
last_lines = lines[-2:]
print(last_lines)
a_file
# Out:
# ['\n', 'Emma Watson\n']
# ['Sevil Huseynli\n', 'Khamanna Iskandarova']
# <_io.TextIOWrapper name='../Downloads/student_names.txt' mode='r' encoding='UTF-8'>

# %%
last_lines = lines[-2:]
print(last_lines)
a_file
# Out:
# ['Sevil Huseynli\n', 'Khamanna Iskandarova']
# <_io.TextIOWrapper name='../Downloads/student_names.txt' mode='r' encoding='UTF-8'>

# %%
search = "This is the line I'm looking for.\n"
with open("../Downloads/student_names.txt") as file:
    if any(line == search for line in file):
        print("Found it!")
    else:
        print("Move along.")
# Out:
# Move along.

# %%
for i in range(65, 65+26):
    filename = chr(i)+'.txt'
    print(filename)
    with open(chr(i) + ".txt", "w") as file:
        file.writelines(chr(i))
        print(file)
# Out:
# A.txt
# <_io.TextIOWrapper name='A.txt' mode='w' encoding='UTF-8'>
# B.txt
# <_io.TextIOWrapper name='B.txt' mode='w' encoding='UTF-8'>
# C.txt
# <_io.TextIOWrapper name='C.txt' mode='w' encoding='UTF-8'>
# D.txt
# <_io.TextIOWrapper name='D.txt' mode='w' encoding='UTF-8'>
# E.txt
# <_io.TextIOWrapper name='E.txt' mode='w' encoding='UTF-8'>
# F.txt
# <_io.TextIOWrapper name='F.txt' mode='w' encoding='UTF-8'>
# G.txt
# <_io.TextIOWrapper name='G.txt' mode='w' encoding='UTF-8'>
# H.txt
# <_io.TextIOWrapper name='H.txt' mode='w' encoding='UTF-8'>
# I.txt
# <_io.TextIOWrapper name='I.txt' mode='w' encoding='UTF-8'>
# J.txt
# <_io.TextIOWrapper name='J.txt' mode='w' encoding='UTF-8'>
# K.txt
# <_io.TextIOWrapper name='K.txt' mode='w' encoding='UTF-8'>
# L.txt
# <_io.TextIOWrapper name='L.txt' mode='w' encoding='UTF-8'>
# M.txt
# <_io.TextIOWrapper name='M.txt' mode='w' encoding='UTF-8'>
# N.txt
# <_io.TextIOWrapper name='N.txt' mode='w' encoding='UTF-8'>
# O.txt
# ...

# %%
print(filename)
# Out:
# Z.txt
